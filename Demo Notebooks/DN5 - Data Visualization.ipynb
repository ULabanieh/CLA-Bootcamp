# %% [markdown]
# # Data Visualization
#
# ### What is Data Visualization
#
# Data visualization is the graphical representation of data and information. It is an essential tool for data scientists, analysts, and decision-makers to help them make sense of complex data sets. The power of data visualization is that it helps us see patterns, relationships, and trends that might not be apparent from raw data or tables.
#
# ### Significance of Data Visualization
#
# The human brain is wired to process visual information faster than any other type of information. We process visuals 60,000 times faster than text, and 90% of the information transmitted to our brain is visual. This is why data visualization is so important; it allows us to process and analyze large amounts of data quickly and efficiently.
#
# ### Data Visualization and Statistical Conclusions
#
# Data visualization is not just a way to present data; it also plays a crucial role in statistical analysis. When we analyze data, we often use statistical tests to determine if there are significant differences or relationships between variables. Data visualization helps us visualize the results of these statistical tests, making it easier to draw conclusions from the data.

# %% [markdown]
# ## Library for Data Visualization in Python: Seaborn
#
# Seaborn is built on top of Matplotlib, which is a low-level data visualization library in Python. Seaborn provides a high-level interface for creating statistical graphics, making it easier to create complex visualizations with fewer lines of code. Seaborn provides several functions for creating different types of plots, including:
#
# - Line plots
# - Scatter plots
# - Histograms
# - Density plots
# - Bar plots
# - Box plots
#
# Read more about Seaborn [here](https://seaborn.pydata.org/)
# Read more about Matplotlib [here](https://matplotlib.org/)

# %% [markdown]
# **Installing Seabon**

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from seaborn) (2.4.3)
# Requirement already satisfied: pandas>=1.2 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/usama-labanieh/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %% [markdown]
# **For this session in order to demonstrate the graphs we will be using the housing-prices dataset**
#
# Lets peek into the dataset

# %%
# import pandas
import pandas as pd

# loading data into DataFrame
housing_df = pd.read_csv("Datasets/house-prices.csv")

# printing out some of the dataset
print(housing_df.head(10))
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East
# 5     6  114600  1780         3          2       2    No        North
# 6     7  151600  1830         3          3       3   Yes         West
# 7     8  150700  2160         4          2       2    No         West
# 8     9  119200  2110         4          2       3    No         East
# 9    10  104000  1730         3          3       3    No         East

# %% [markdown]
# ## Scatter Plots
#
# A scatter plot identifies a possible relationship between changes observed in two different sets of variables. It provides a visual and statistical means to test the strength of a relationship between two variables.
#
# <br>
# <div>
#     <img src="assests/scatter_plot.jpg" width=70%/>
# </div>
#
#
# Read more about Scatter Plot in Seaborn [here](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)

# %% [markdown]
# ### Plotting a Scatter Plot in Python

# %%
# import seaborn
import seaborn as sns

# simple scatter plot
sns.scatterplot(x='Price', y='SqFt', data=housing_df)
# Out:
# <Axes: xlabel='Price', ylabel='SqFt'>

# %% [markdown]
# ### When to use a Scatter Plot
#
# - When you have paired numerical data
# - When your dependent variable may have multiple values for each value of your independent variable
# - When trying to determine whether the two variables are related

# %% [markdown]
# ## Histogram
#
# A histogram is used to visualize the distribution of a continuous variable. The x-axis represents the range of values of the variable, and the y-axis represents the frequency or proportion of observations within each range. Histograms are useful for identifying the shape of the distribution, as well as for identifying outliers and skewness in the data.
#
# <div>
#     <img src="assests/histogram.png" width=70%/>
# </div>
#
# Read more about Seaborn Histogram [here](https://seaborn.pydata.org/generated/seaborn.histplot.html)

# %% [markdown]
# ### Plotting a Histogram in Python

# %%
column = "Bedrooms"

sns.histplot(data=housing_df, x=column)
# Out:
# <Axes: xlabel='Bedrooms', ylabel='Count'>

# %% [markdown]
# ### Why use Histograms
#
# One of the main advantages of using a histogram is that it can help you analyze the distribution and variation of a continuous variable, which can reveal important insights about the process or the population.

# %% [markdown]
# ## Line Plot
#
# A line plot is used to show trends over time or to display relationships between two variables.
#
# <div>
#     <img src="assests/lineplot.png" width=75%/>
# </div>
#
# Read more about Seaborn Lineplot [here](https://seaborn.pydata.org/generated/seaborn.lineplot.html)

# %% [markdown]
# ### Plotting Line Plot in Python

# %%
sns.lineplot(data=housing_df, x="Price", y="Bedrooms")
# housing_df["Price"].to_numpy()
# Out:
# <Axes: xlabel='Price', ylabel='Bedrooms'>

# %% [markdown]
# ### When to use a Line Plot
#
# 1. Trend Visualization:
#     1. Use a line plot when you want to show the overall trend or pattern in your data over a continuous variable, such as time.
#
# 2. Comparing Multiple Trends:
#     1. Employ a line plot when you need to compare multiple trends on the same graph, making it easy to see relative changes.
# 3. Sequential Data Display:
#     1. Opt for a line plot when you want to display the progression of values in a sequential order, highlighting the flow of data.
#
# 4. Correlation Assessment:
#     1. Use a line plot to assess the correlation between two variables, observing how changes in one variable relate to changes in another.
#
# 5. Frequency Distribution:
#     1. Choose a line plot when representing the distribution of values, particularly when the x-axis represents categories or bins.
#
# 6. Monitoring Progress:
#     1. Utilize a line plot when you need to monitor the progress of a variable over time or against specific milestones.

# %% [markdown]
# ## Density Plot
#
# A density plot is used to estimate the probability density function of a continuous variable.
#
# <div>
#     <img src="assests/densityplot.jpg" width=65%/>
# </div>
#
# Read more about Seaborn Density Plot [here](https://seaborn.pydata.org/generated/seaborn.kdeplot.html)

# %% [markdown]
# ### Density Plot in Python

# %%
sns.kdeplot(data=housing_df, x="Price", y="Bedrooms")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.kdeplot(data=housing_df, x="Price", y="Bedrooms")
#
# File ~/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages/seaborn/distributions.py:1715, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1701     p.plot_univariate_density(
#    1702         multiple=multiple,
#    1703         common_norm=common_norm,
#    (...)   1710         **plot_kws,
#    1711     )
#    1713 else:
# -> 1715     p.plot_bivariate_density(
#    1716         common_norm=common_norm,
#    1717         fill=fill,
#    1718         levels=levels,
#    1719         thresh=thresh,
#    1720         legend=legend,
#    1721         color=color,
#    1722         warn_singular=warn_singular,
#    1723         cbar=cbar,
#    1724         cbar_ax=cbar_ax,
#    1725         cbar_kws=cbar_kws,
#    1726         estimate_kws=estimate_kws,
#    1727         **kwargs,
#    1728     )
#    1730 return ax
#
# File ~/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages/seaborn/distributions.py:1176, in _DistributionPlotter.plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, warn_singular, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1173 # Pop the label kwarg which is unused by contour_func (but warns)
#    1174 contour_kws.pop("label", None)
# -> 1176 cset = contour_func(
#    1177     xx, yy, density,
#    1178     levels=draw_levels[key],
#    1179     **contour_kws,
#    1180 )
#    1182 # Add a color bar representing the contour heights
#    1183 # Note: this shows iso densities, not iso proportions
#    1184 # See more notes in histplot about how this could be improved
#    1185 if cbar:
#
# File ~/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages/matplotlib/axes/_axes.py:6779, in Axes.contour(self, *args, **kwargs)
#    6768 """
#    6769 Plot contour lines.
#    6770
#    (...)   6776 %(contour_doc)s
#    6777 """
#    6778 kwargs['filled'] = False
# -> 6779 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6780 self._request_autoscale_view()
#    6781 return contours
#
# File ~/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages/matplotlib/contour.py:701, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     697 if self.negative_linestyles is None:
#     698     self.negative_linestyles = \
#     699         mpl.rcParams['contour.negative_linestyle']
# --> 701 kwargs = self._process_args(*args, **kwargs)
#     702 self._process_levels()
#     704 self._extend_min = self.extend in ['min', 'both']
#
# File ~/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages/matplotlib/contour.py:1319, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1316         corner_mask = mpl.rcParams['contour.corner_mask']
#    1317 self._corner_mask = corner_mask
# -> 1319 x, y, z = self._contour_args(args, kwargs)
#    1321 contour_generator = contourpy.contour_generator(
#    1322     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1323     line_type=contourpy.LineType.SeparateCode,
#    1324     fill_type=contourpy.FillType.OuterCode,
#    1325     chunk_size=self.nchunk)
#    1327 t = self.get_transform()
#
# File ~/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages/matplotlib/contour.py:1370, in QuadContourSet._contour_args(self, args, kwargs)
#    1368     _api.warn_external('Log scale: values of z <= 0 have been masked')
#    1369     self.zmin = z.min().astype(float)
# -> 1370 self._process_contour_level_args(args, z.dtype)
#    1371 return (x, y, z)
#
# File ~/Downloads/CLA Notebooks/CLA Bootcamp Repo/.venv/lib/python3.12/site-packages/matplotlib/contour.py:1030, in ContourSet._process_contour_level_args(self, args, z_dtype)
#    1028     raise ValueError("Filled contours require at least 2 levels.")
#    1029 if len(self.levels) > 1 and np.min(np.diff(self.levels)) <= 0.0:
# -> 1030     raise ValueError("Contour levels must be increasing")
#
# ValueError: Contour levels must be increasing

# %% [markdown]
# ## Heat Maps
#
# A heatmap is used to visualize the relationship between two categorical variables. The colors in the heatmap represent the frequency or proportion of the combination of the two variables. Heatmaps are useful for identifying patterns and trends in the data, as well as for identifying areas with high or low frequency or proportion.
#
# <div>
#     <img src="assests/heatmap.png" width=65%/>
# </div>
#
# Read more about Seaborn HeatMap [here](https://seaborn.pydata.org/generated/seaborn.heatmap.html)

# %% [markdown]
# ### HeatMaps in Python

# %%
data = housing_df[["Bathrooms", "Bedrooms", "SqFt", "Offers"]]
sns.heatmap(data.corr())
# Out:
# <Axes: >
