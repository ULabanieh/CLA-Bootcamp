# %%
# !pip install scikit-learn
# Out:
# WARNING: Skipping sklearn as it is not installed.
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd

# %%
# Load the "Iris" dataset into a Pandas DataFrame using the code provided above.
from sklearn.datasets import load_iris
data = load_iris()
df = pd.DataFrame(data["data"], columns=data["feature_names"])
df["target"] = data["target"]
df["target"] = df["target"].map({0: "setosa", 1: "versicolor", 2: "virginica"})

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         target
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica
#
# [150 rows x 5 columns]

# %%
# Display the first 5 rows of the DataFrame using the "head()" method.
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Check the shape of the DataFrame using the "shape" attribute.
df.shape
# Out:
# (150, 5)

# %%
# Check the data types of each column using the "dtypes" attribute.
df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                object
# dtype: object

# %%
# Check for missing values in the DataFrame using the "isnull()" method and the "sum()" method.
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
# Calculate the mean, median, and mode for the "sepal length (cm)" column.
print("Mean: ", round(df["sepal length (cm)"].mean(), 1))
print("Median: ", df["sepal length (cm)"].median())
print("Mode: ", df["sepal length (cm)"].mode())
# Out:
# Mean:  5.8
# Median:  5.8
# Mode:  0    5.0
# Name: sepal length (cm), dtype: float64

# %%
# Calculate the range, variance, and standard deviation for the "petal width (cm)" column.
print("Range: ", df["petal width (cm)"].max() - df["petal width (cm)"].min())
print("Variance: ", round(df["petal width (cm)"].var(), 1))
print("Standard Deviation: ", round(df["petal width (cm)"].std(), 1))
# Out:
# Range:  2.4
# Variance:  0.6
# Standard Deviation:  0.8

# %%
# Calculate the skewness and kurtosis for the "sepal width (cm)" column.
print("Skewness: ", round(df["sepal width (cm)"].skew(), 1))
print("Kurtosis: ", round(df["sepal width (cm)"].kurtosis(), 1))
# Out:
# Skewness:  0.3
# Kurtosis:  0.2

# %%
# Count the number of unique values in the "target" column using the "nunique()" method.
print("Count Unique:", df["target"].nunique())
# Out:
# Count Unique: 3

# %%
# Group the data by the "target" column and calculate the mean for each group using the "groupby()" method and the "mean()" method.
round(df.groupby(["target"]).mean(), 1)
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# setosa                    5.0               3.4                1.5
# versicolor                5.9               2.8                4.3
# virginica                 6.6               3.0                5.6
#
#             petal width (cm)
# target
# setosa                   0.2
# versicolor               1.3
# virginica                2.0
